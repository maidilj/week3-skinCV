# %% [markdown]
# # 03 — Research comparison (Phase 3.5)
#
# **TODO (Phase 3.5):** consolidate all runs into one comparison table (backbone x strategy x aug vs test accuracy + macro-F1), side-by-side curves, and a written conclusion on which combo wins and *why*. Optional Gradio demo cell (upload -> prediction + confidence bars).
