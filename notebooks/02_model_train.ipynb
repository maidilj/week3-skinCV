# %% [markdown]
# # 02 — Model + Train (Phases 2 & 3, rubric 30% + 30%)
#
# **TODO (Phase 2):** load ResNet-50 and ViT-B/16 (ImageNet weights), swap to 7-way heads, implement head-only vs full fine-tune switches, weighted `CrossEntropyLoss`. Sanity: `[B, 7]` forward pass + overfit one tiny batch.
#
# **TODO (Phase 3):** wandb logging (config, per-epoch loss/acc, confusion matrix), core grid 2 backbones x 2 strategies = 4 runs + aug ablation on stronger backbone = 2 (total 6), AMP, best checkpoint to Drive, test table (acc + macro-F1), curves, confusion matrix, export `models/best.pth`.
